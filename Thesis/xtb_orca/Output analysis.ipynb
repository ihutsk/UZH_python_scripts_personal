# %% [markdown]
# # Data collection from the input file

# %% [markdown]
# This code is used to analyse the geometries after xtb_dock - crest.
# The code works with file `crest_ensemble.xyz` and should:
# 1. Extract geometry values (alpha, beta, distance, energy)
# 2. Add to the pandas dataframe along with the name of the folder
# 3. Add the corresponding `structure_x` code

# %%
import pandas as pd
import numpy as np
import os, re

# %% [markdown]
# Get the atom numbers from the Avogadro

# %%
# global variables
loc_s = 127
loc_cs = 132
loc_n = 1
loc_cn = 9

# %%
df = pd.read_csv('crest_ensemble.xyz')

# %%
#reading number of atoms

for col in df.columns:
    atoms = int(col)
    
n_rows = atoms + 2

#Creating dataframes of separate atoms

df_s = df[df.index % n_rows == loc_s] # for S
df_cs = df[df.index % n_rows == loc_cs] # for C4 in sulfonate
df_n = df[df.index % n_rows == loc_n] # for N
df_cn = df[df.index % n_rows == loc_cn] # for C4 in pyridinium

#Formatting strings, splitting into columns, delete the element column, setting type to float

df_s= df_s[df_s.columns[0]].str.replace(' +', ' ', regex=True).str.split(' ', expand=True)
df_s = df_s.drop(columns=[0, 1]).astype('float64')

df_cs= df_cs[df_cs.columns[0]].str.replace(' +', ' ', regex=True).str.split(' ', expand=True)
df_cs = df_cs.drop(columns=[0, 1]).astype('float64')


df_n= df_n[df_n.columns[0]].str.replace(' +', ' ', regex=True).str.split(' ', expand=True)
df_n = df_n.drop(columns=[0, 1]).astype('float64')


df_cn= df_cn[df_cn.columns[0]].str.replace(' +', ' ', regex=True).str.split(' ', expand=True)
df_cn = df_cn.drop(columns=[0, 1]).astype('float64')

# xTB gfn2 energy values

df_e = df[df.index % n_rows == 0].astype('float64')

# %%
# Creating numpy arrays

arr_s = np.array(df_s)
arr_cs = np.array(df_cs)
arr_n = np.array(df_n)
arr_cn = np.array(df_cn)
arr_e = np.array(df_e)

# %%
# functions to calculate angle

def vectors(arr1, arr2):
    arr3 = arr2 - arr1
    return arr3

def vector_len(arr):
    v_len = np.sqrt((arr[:,0])**2 + (arr[:,1])**2 + (arr[:,2])**2)
    return v_len

def dot_product(arr1, arr2):
    dot_pr = arr1[:,0]*arr2[:,0] + arr1[:,1]*arr2[:,1] + arr1[:,2]*arr2[:,2]
    return dot_pr

def angle(arr1, arr2):
    cos_a = (dot_product(arr1, arr2))/(vector_len(arr1)*vector_len(arr2))
    result = np.degrees(np.arccos(cos_a))
    return result

# %%
# alpha angle
#vector N - C(N)
vector_N_Cn = vectors(arr_n, arr_cn)
     
#vector N - C(S)
vector_N_Cs = vectors(arr_n, arr_cs)
        
alpha_ang = np.around(angle(vector_N_Cn, vector_N_Cs), decimals=1)

# beta angle

vector_S_Cn = vectors(arr_s, arr_cn)
        
#vector S - C(S)
vector_S_Cs = vectors(arr_s, arr_cs)
        
beta_ang = np.around(angle(vector_S_Cs, vector_S_Cn), decimals=1)

# distance
ns_dist = np.around(vector_len(vectors(arr_n, arr_s)), decimals=1)

# combine into dataframe

stacked = np.column_stack((alpha_ang, beta_ang, ns_dist, arr_e)) # need this because numpy nicely transforms everything

inputs = pd.DataFrame(data=stacked, columns=['alpha_inp', 'beta_inp', 'distance_inp', 'energy_inp'])

inputs['rel_energy_inp_kcal'] = (inputs['energy_inp'] - inputs['energy_inp'].min())*627.509

# %%
# label each structure according to how the inputs were created
names = []
for _ in range(1, inputs.shape[0]+1):
    names.append(f'structure_{_}')
inputs['name'] = names

# %%
inputs
# Out:
#     alpha_inp  beta_inp  distance_inp  energy_inp  rel_energy_inp_kcal  \
# 0       176.4     178.8           4.4 -311.160925             0.000000
# 1       176.7     178.7           4.4 -311.160894             0.019810
# 2       176.1     177.8           4.4 -311.160432             0.309789
# 3       178.5     177.7           4.4 -311.160328             0.374949
# 4       176.6     179.4           4.4 -311.160306             0.388930
# ..        ...       ...           ...         ...                  ...
# 88      121.1     165.6           6.3 -311.140752            12.659266
# 89      130.6     162.5           6.2 -311.140566            12.775776
# 90      138.6     148.7           6.5 -311.140126            13.051760
# 91      101.8     142.2           7.7 -311.138670            13.965627
# 92      108.0     150.5           7.9 -311.138529            14.053692
#
#             name
# 0    structure_1
# 1    structure_2
# 2    structure_3
# 3    structure_4
# 4    structure_5
# ..           ...
# 88  structure_89
# 89  structure_90
# 90  structure_91
# 91  structure_92
# 92  structure_93
#
# [93 rows x 6 columns]

# %% [markdown]
# # Analysis of the geometric parameters

# %% [markdown]
# First let's look at the distributions of angles and distances

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_context("paper")
sns.set_style("white", {"axes.edgecolor": "black"})
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(10,5))
axs = axs.flatten()

sns.boxplot(inputs['alpha_inp'], ax=axs[0])
ax=axs[0]
ax.set_ylabel('degrees')
ax.set_xlabel('alpha')
ax.set_ylim([0,180])
ax.set_xticks([])

sns.boxplot(inputs['beta_inp'], ax=axs[1])
ax=axs[1]
ax.set_ylabel('degrees')
ax.set_ylim([0,180])
ax.set_xlabel('beta')
ax.set_xticks([])

sns.boxplot(inputs['distance_inp'], ax=axs[2])
ax=axs[2]
ax.set_ylabel('angstrom')
ax.set_ylim([inputs['distance_inp'].min()-1, inputs['distance_inp'].max()+1])
ax.set_xlabel('distance')
ax.set_xticks([])

sns.histplot(inputs['alpha_inp'], ax=axs[3])
ax=axs[3]
ax.set_xlim([40,180])
ax.set_xlabel('alpha')

sns.histplot(inputs['beta_inp'], ax=axs[4])
ax=axs[4]
ax.set_xlim([40,180])
ax.set_xlabel('beta')

sns.histplot(inputs['distance_inp'], ax=axs[5])
ax.set_xlabel('distance')
plt.tight_layout()
plt.show()

# %% [markdown]
# Let's look at the angles more closely.

# %%
sns.set_context("talk")
sns.set_style("whitegrid", {"axes.edgecolor": "black"})

fig = plt.figure()
sns.scatterplot(data=inputs, x='alpha_inp', y='beta_inp')

plt.xlim(0, 180)
plt.ylim(0, 180)
plt.xlabel('alpha')
plt.ylabel('beta')

plt.gcf().set_size_inches(8, 8)

plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.scatterplot(data=inputs, x='alpha_inp', y='beta_inp')

plt.xlim(140, 180)
plt.ylim(140, 180)
plt.xlabel('alpha')
plt.ylabel('beta')

plt.gcf().set_size_inches(8, 8)

plt.tight_layout()
plt.show()

# %% [markdown]
# Now with energy:

# %%
fig = plt.figure()
sns.scatterplot(data=inputs, x='alpha_inp', y='beta_inp', hue='rel_energy_inp_kcal', palette='icefire')

plt.xlim(0, 180)
plt.ylim(0, 180)
plt.xlabel('alpha')
plt.ylabel('beta')
plt.gcf().set_size_inches(8, 8)

plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.scatterplot(data=inputs, x='alpha_inp', y='beta_inp', hue='rel_energy_inp_kcal', palette='Blues_d')

plt.xlim(140, 180)
plt.ylim(140, 180)
plt.xlabel('alpha')
plt.ylabel('beta')
plt.gcf().set_size_inches(8, 8)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Clustering
#
# Clustering will be performed using KMeans from scikit-learn (because it's simple).

# %%
import warnings
from sklearn.cluster import KMeans

# %% [markdown]
# First we find the best number of clusters from the elbow rule, using only alpha and beta angles.

# %%
warnings.filterwarnings('ignore')
inertias = []
for i in range(1,11): # more than 10 clusters make no sense for 93 samples
    model = KMeans(n_clusters=i, random_state=123, max_iter=1000)
    model.fit(inputs[['alpha_inp', 'beta_inp']])
    inertias.append(model.inertia_)

# %%
sns.set_context("notebook")
sns.set_style("whitegrid", {"axes.edgecolor": "black"})
fig = plt.figure(figsize=(6,4))
sns.lineplot(x=range(1,11), y=inertias, markers=True, marker='o')
plt.xlabel('# of clusters')
plt.ylabel('inertia')
plt.tight_layout()
plt.show()

# %% [markdown]
# 4 clusters look like a reasonable solution here, let's viasualize them

# %%
model = KMeans(n_clusters=4, random_state=123, max_iter=1000)
model.fit(inputs[['alpha_inp', 'beta_inp']])
inputs['cluster_inp'] = model.labels_

# %%
sns.set_context("talk")
sns.set_style("whitegrid", {"axes.edgecolor": "black"})

fig = plt.figure()
sns.scatterplot(data=inputs, x='alpha_inp', y='beta_inp', hue='cluster_inp', palette='seismic')


plt.xlim(0, 180)
plt.ylim(0, 180)
plt.xlabel('alpha')
plt.ylabel('beta')
plt.gcf().set_size_inches(8, 8)


plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.scatterplot(data=inputs, x='alpha_inp', y='beta_inp', hue='cluster_inp', palette='seismic')


plt.xlim(140, 180)
plt.ylim(140, 180)
plt.xlabel('alpha')
plt.ylabel('beta')
plt.gcf().set_size_inches(8, 8)


plt.tight_layout()
plt.show()

# %% [markdown]
# # Some statistics for each cluster

# %%
sns.set_context("notebook")
fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(10,8), sharey=True)
axs = axs.flatten()

for i in range(4):
    data = inputs[inputs['cluster_inp']==i]
    
    sns.boxplot(data=data, x='alpha_inp', ax = axs[i])
    
    ax = axs[i]
    ax.set_xlabel('')
    ax.axvline(x=data['alpha_inp'].mean(), zorder=9, c='red', alpha=0.7)
    
for i in range(4):
    data = inputs[inputs['cluster_inp']==i]
    
    sns.boxplot(data=data, x='beta_inp', ax = axs[i+4])
    
    ax = axs[i+4]
    ax.set_xlabel('')
    
    ax.axvline(x=data['beta_inp'].mean(), zorder=9, c='red', alpha=0.7)
for i in range(4):
    data = inputs[inputs['cluster_inp']==i]
    
    sns.boxplot(data=data, x='distance_inp', ax = axs[i+8])
    
    ax = axs[i+8]
    ax.set_xlabel('')
    ax.axvline(x=data['distance_inp'].mean(), zorder=9, c='red', alpha=0.7)
    
for i in range(4):
    data = inputs[inputs['cluster_inp']==i]
    
    sns.boxplot(data=data, x='rel_energy_inp_kcal', ax = axs[i+12])
    
    ax = axs[i+12]
    ax.set_xlabel(f'cluster_{i}')
    ax.axvline(x=data['rel_energy_inp_kcal'].mean(), zorder=9, c='red', alpha=0.7)

ax = axs[0]
ax.set_ylabel('alpha')
ax = axs[4]
ax.set_ylabel('beta')
ax = axs[8]
ax.set_ylabel('distance')
ax = axs[12]
ax.set_ylabel('energy')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data collection of the output files
#
# The algorithm iterates through folders `structure_x`, extracts geometry data from the xyz file, extracts R2SCAN-3c SP energy in vacuum and different solvents, extracts $\Delta G_{RRHO}$ values, and adds it as row to the pandas DataFrame along with structure.

# %%
# list of folders
folders = []
for dr in os.scandir():
    if dr.is_dir() and 'structure' in dr.name:
        folders.append(dr.name)

# %% [markdown]
# First we will create functions for each process (xyz file, out file etc.), then iterate through `folders` list executing those functions.

# %% [markdown]
# ### Extracting geometry

# %%
def geometry_from_xyz(folder):
    pattern_xyz = 'struc_[0-9]+_r2scan_opt\.xyz'
    file_name = [i for i in os.listdir(f'{folder}/') if re.findall(pattern_xyz, i)][0] # get the name of correct xyz
    with open(f'{folder}/{file_name}', 'r', encoding='utf-8') as xyz:
        lines = xyz.readlines()
        no_of_atoms = int(lines[0][:-1]) # get number of atoms
        
        # get the lines containing the atoms we need
        
        n_coord = np.array([float(i) for i in lines[loc_n+1].strip().split()[1:]])
        cn_coord = np.array([float(i) for i in lines[loc_cn+1].strip().split()[1:]])
        s_coord = np.array([float(i) for i in lines[loc_s+1].strip().split()[1:]])
        cs_coord = np.array([float(i) for i in lines[loc_cs+1].strip().split()[1:]])
        
        # calculate the corresponding angles
        # alpha
        
        vector_n_cn = cn_coord - n_coord
        vector_n_cs = cs_coord - n_coord
        len_n_cn = np.sqrt(np.square(vector_n_cn).sum())
        len_n_cs = np.sqrt(np.square(vector_n_cs).sum())
        
        cos_a = np.dot(vector_n_cn, vector_n_cs)/(len_n_cn*len_n_cs)
        alpha = np.around(np.degrees(np.arccos(cos_a)), decimals=1)
        
        # beta
        
        vector_s_cn = cn_coord - s_coord
        vector_s_cs = cs_coord - s_coord
        len_s_cn = np.sqrt(np.square(vector_s_cn).sum())
        len_s_cs = np.sqrt(np.square(vector_s_cs).sum())
        
        cos_b = np.dot(vector_s_cs, vector_s_cn)/(len_s_cs*len_s_cn)
        beta = np.around(np.degrees(np.arccos(cos_b)), decimals=1)
        
        # distance
        dist = np.around(np.sqrt(np.square(n_coord - s_coord).sum()), decimals=1)
               
        
        
    return alpha, beta, dist

# %% [markdown]
# ### SPE in vacuum

# %%
def r2scan_spe_vacuum(folder):
    pattern_out = 'struc_[0-9]+_r2scan_opt\.out'
    file_name = [i for i in os.listdir(f'{folder}/') if re.findall(pattern_out, i)][0] # get the name of correct out
    with open(f'{folder}/{file_name}', 'r', encoding='utf-8') as out:
        lines = out.readlines()
        for line in lines:
            if 'FINAL SINGLE POINT ENERGY' in line:
                energy_vacuum = re.findall(r'[-.\d]*[.][\d]+', line)
    return np.around(float(energy_vacuum[0]), decimals=6)

# %% [markdown]
# ### $\Delta G_{RRHO}$ from single point hessian

# %%
def hess_reader(folder):
    pattern_out = 'struc_[0-9]+_r2scan_opt_bhess\.out'
    file_name = [i for i in os.listdir(f'{folder}/SPH/') if re.findall(pattern_out, i)][0] # get the name of correct out
    
    with open(f'{folder}/SPH/{file_name}', 'r', encoding='utf-8') as hess:
        lines = hess.readlines()
        for line in lines:
            if 'G(RRHO) contrib' in line:
                G_rrho = re.findall(r'[-.\d]*[.][\d]+', line)
        
    return np.around(float(G_rrho[0]), decimals=6)

# %% [markdown]
# ### SPE for each solvent

# %%
def r2scan_spe_solvent(folder):
    energies = [folder]
    for solvent in solvents:
        with open(f'{folder}/{solvent}/{folder}_r2scan_{solvent}.out', 'r', encoding='utf-8') as opt:
            lines = opt.readlines()
            for line in lines:
                if 'FINAL SINGLE POINT ENERGY' in line:
                    energy_sol = re.findall(r'[-.\d]*[.][\d]+', line)
                    energies.append(np.around(float(energy_sol[0]), decimals=6))
    return energies

# %%
solvents = ['benzene', 'CH2Cl2', 'water']
en = []
for folder in folders:
    energies = r2scan_spe_solvent(folder)
    en.append(energies)

# %%
solv_df = pd.DataFrame(en, columns=['name', 'benzene', 'CH2Cl2', 'water'])

# %% [markdown]
# ### Iterating through the folders and combining the data

# %%
outputs = pd.DataFrame(columns=['name', 'alpha_opt', 'beta_opt', 'distance_opt', 'SPE_vac', 'dG'])
for folder in folders:
    alpha, beta, dist = geometry_from_xyz(folder)
    spe = r2scan_spe_vacuum(folder)
    dG = hess_reader(folder)
    
    outputs.loc[len(outputs.index)] = [folder, alpha, beta, dist, spe, dG]

# %%
outputs['energy_opt_vac'] = outputs['SPE_vac'] + outputs['dG']

# %%
outputs # contains the output data
# Out:
#             name  alpha_opt  beta_opt  distance_opt      SPE_vac        dG  \
# 0    structure_1      169.9     176.1           4.6 -4651.819516  2.046003
# 1   structure_10      169.9     176.1           4.6 -4651.819510  2.045981
# 2   structure_11      171.9     177.6           4.6 -4651.819536  2.045704
# 3   structure_12      171.5     179.5           4.6 -4651.819471  2.044866
# 4   structure_13      171.5     179.5           4.6 -4651.819493  2.045063
# ..           ...        ...       ...           ...          ...       ...
# 88   structure_9      169.9     176.2           4.6 -4651.819517  2.045993
# 89  structure_90      149.6     171.4           4.5 -4651.815773  2.045991
# 90  structure_91      170.1     175.2           4.6 -4651.819200  2.046323
# 91  structure_92       87.4     169.9           5.9 -4651.815597  2.045806
# 92  structure_93       79.3     156.9           5.7 -4651.815686  2.047212
#
#     energy_opt_vac
# 0     -4649.773513
# 1     -4649.773529
# 2     -4649.773832
# 3     -4649.774605
# 4     -4649.774430
# ..             ...
# 88    -4649.773524
# 89    -4649.769782
# 90    -4649.772877
# 91    -4649.769791
# 92    -4649.768474
#
# [93 rows x 7 columns]

# %%
combined = outputs.merge(solv_df, on='name')

# %%
combined['benzene_opt'] = combined['benzene'] + combined['dG']
combined['CH2Cl2_opt'] = combined['CH2Cl2'] + combined['dG']
combined['water_opt'] = combined['water'] + combined['dG']

# %%
combined.head(5)
# Out:
#            name  alpha_opt  beta_opt  distance_opt      SPE_vac        dG  \
# 0   structure_1      169.9     176.1           4.6 -4651.819516  2.046003
# 1  structure_10      169.9     176.1           4.6 -4651.819510  2.045981
# 2  structure_11      171.9     177.6           4.6 -4651.819536  2.045704
# 3  structure_12      171.5     179.5           4.6 -4651.819471  2.044866
# 4  structure_13      171.5     179.5           4.6 -4651.819493  2.045063
#
#    energy_opt_vac      benzene       CH2Cl2        water  benzene_opt  \
# 0    -4649.773513 -4651.843632 -4651.868105 -4651.878492 -4649.797629
# 1    -4649.773529 -4651.843633 -4651.868112 -4651.878501 -4649.797652
# 2    -4649.773832 -4651.843657 -4651.868128 -4651.878510 -4649.797953
# 3    -4649.774605 -4651.843760 -4651.868398 -4651.878851 -4649.798894
# 4    -4649.774430 -4651.843747 -4651.868350 -4651.878790 -4649.798684
#
#     CH2Cl2_opt    water_opt
# 0 -4649.822102 -4649.832489
# 1 -4649.822131 -4649.832520
# 2 -4649.822424 -4649.832806
# 3 -4649.823532 -4649.833985
# 4 -4649.823287 -4649.833727

# %% [markdown]
# # Manually get cation and anion r2scan energies

# %%
cation_dG = 1.020778
cation_spe_vac = np.around(cation_dG - 2042.082994076759, decimals=6)
cation_spe_benzene = np.around(cation_dG - 2042.112010110078, decimals=6)
cation_spe_CH2Cl2 = np.around(cation_dG - 2042.137675855720, decimals=6)
cation_spe_water = np.around(cation_dG - 2042.147422099356, decimals=6)

# %%
anion_dG = 0.993800
anion_spe_vac = np.around(anion_dG - 2609.616974162284, decimals=6)
anion_spe_benzene = np.around(anion_dG - 2609.655478543323, decimals=6)
anion_spe_CH2Cl2 = np.around(anion_dG - 2609.692657286503, decimals=6)
anion_spe_water = np.around(anion_dG - 2609.707742943956, decimals=6)

# %%
combined['association_vacuum'] = (combined['energy_opt_vac'] - (cation_spe_vac+anion_spe_vac))*627.509
combined['association_benzene'] = (combined['benzene_opt'] - (cation_spe_benzene+anion_spe_benzene))*627.509
combined['association_CH2Cl2'] = (combined['CH2Cl2_opt'] - (cation_spe_CH2Cl2+anion_spe_CH2Cl2))*627.509
combined['association_water'] = (combined['water_opt'] - (cation_spe_water+anion_spe_water))*627.509

# %%
combined.head(5)
# Out:
#            name  alpha_opt  beta_opt  distance_opt      SPE_vac        dG  \
# 0   structure_1      169.9     176.1           4.6 -4651.819516  2.046003
# 1  structure_10      169.9     176.1           4.6 -4651.819510  2.045981
# 2  structure_11      171.9     177.6           4.6 -4651.819536  2.045704
# 3  structure_12      171.5     179.5           4.6 -4651.819471  2.044866
# 4  structure_13      171.5     179.5           4.6 -4651.819493  2.045063
#
#    energy_opt_vac      benzene       CH2Cl2        water  benzene_opt  \
# 0    -4649.773513 -4651.843632 -4651.868105 -4651.878492 -4649.797629
# 1    -4649.773529 -4651.843633 -4651.868112 -4651.878501 -4649.797652
# 2    -4649.773832 -4651.843657 -4651.868128 -4651.878510 -4649.797953
# 3    -4649.774605 -4651.843760 -4651.868398 -4651.878851 -4649.798894
# 4    -4649.774430 -4651.843747 -4651.868350 -4651.878790 -4649.798684
#
#     CH2Cl2_opt    water_opt  association_vacuum  association_benzene  \
# 0 -4649.822102 -4649.832489          -55.297976           -28.060947
# 1 -4649.822131 -4649.832520          -55.308016           -28.075380
# 2 -4649.822424 -4649.832806          -55.498151           -28.264260
# 3 -4649.823532 -4649.833985          -55.983215           -28.854746
# 4 -4649.823287 -4649.833727          -55.873401           -28.722969
#
#    association_CH2Cl2  association_water
# 0           -3.982800           5.081568
# 1           -4.000997           5.062115
# 2           -4.184858           4.882648
# 3           -4.880137           4.142814
# 4           -4.726398           4.304712

# %%
combined.to_excel('optimized_iPr.xlsx')

# %%
combined.sort_values(by='association_CH2Cl2').head(10)
# Out:
#             name  alpha_opt  beta_opt  distance_opt      SPE_vac        dG  \
# 3   structure_12      171.5     179.5           4.6 -4651.819471  2.044866
# 50  structure_55      171.6     179.5           4.6 -4651.819451  2.044871
# 4   structure_13      171.5     179.5           4.6 -4651.819493  2.045063
# 8   structure_17      171.0     179.4           4.6 -4651.818999  2.044853
# 44   structure_5      170.0     174.3           4.6 -4651.820501  2.046182
# 80  structure_82      158.6     172.9           4.6 -4651.819596  2.045191
# 68  structure_71      158.5     173.1           4.6 -4651.819578  2.045220
# 2   structure_11      171.9     177.6           4.6 -4651.819536  2.045704
# 72  structure_75      170.5     177.6           4.6 -4651.819426  2.045693
# 36  structure_42      173.4     148.8           4.9 -4651.818371  2.045530
#
#     energy_opt_vac      benzene       CH2Cl2        water  benzene_opt  \
# 3     -4649.774605 -4651.843760 -4651.868398 -4651.878851 -4649.798894
# 50    -4649.774580 -4651.843734 -4651.868364 -4651.878814 -4649.798863
# 4     -4649.774430 -4651.843747 -4651.868350 -4651.878790 -4649.798684
# 8     -4649.774146 -4651.843204 -4651.867754 -4651.878168 -4649.798351
# 44    -4649.774319 -4651.844488 -4651.868841 -4651.879173 -4649.798306
# 80    -4649.774405 -4651.843644 -4651.867820 -4651.877975 -4649.798453
# 68    -4649.774358 -4651.843601 -4651.867751 -4651.877895 -4649.798381
# 2     -4649.773832 -4651.843657 -4651.868128 -4651.878510 -4649.797953
# 72    -4649.773733 -4651.843595 -4651.868116 -4651.878521 -4649.797902
# 36    -4649.772841 -4651.842892 -4651.867915 -4651.878556 -4649.797362
#
#      CH2Cl2_opt    water_opt  association_vacuum  association_benzene  \
# 3  -4649.823532 -4649.833985          -55.983215           -28.854746
# 50 -4649.823493 -4649.833943          -55.967528           -28.835294
# 4  -4649.823287 -4649.833727          -55.873401           -28.722969
# 8  -4649.822901 -4649.833315          -55.695189           -28.514009
# 44 -4649.822659 -4649.832991          -55.803748           -28.485771
# 80 -4649.822629 -4649.832784          -55.857714           -28.578015
# 68 -4649.822531 -4649.832675          -55.828221           -28.532834
# 2  -4649.822424 -4649.832806          -55.498151           -28.264260
# 72 -4649.822423 -4649.832828          -55.436028           -28.232257
# 36 -4649.822385 -4649.833026          -54.876290           -27.893403
#
#     association_CH2Cl2  association_water
# 3            -4.880137           4.142814
# 50           -4.855665           4.169170
# 4            -4.726398           4.304712
# 8            -4.484179           4.563245
# 44           -4.332322           4.766558
# 80           -4.313497           4.896453
# 68           -4.252001           4.964851
# 2            -4.184858           4.882648
# 72           -4.184230           4.868842
# 36           -4.160385           4.744596

# %% [markdown]
# # Combine inputs and outputs

# %%
inp_out = combined.merge(inputs, on='name')

# %%
inp_out.sort_values(by='association_benzene').head(10)
# Out:
#             name  alpha_opt  beta_opt  distance_opt      SPE_vac        dG  \
# 25  structure_32      175.0     146.8           4.9 -4651.823922  2.046940
# 26  structure_33      174.9     147.0           4.9 -4651.823902  2.046939
# 3   structure_12      171.5     179.5           4.6 -4651.819471  2.044866
# 49  structure_55      171.6     179.5           4.6 -4651.819451  2.044871
# 4   structure_13      171.5     179.5           4.6 -4651.819493  2.045063
# 77  structure_82      158.6     172.9           4.6 -4651.819596  2.045191
# 66  structure_71      158.5     173.1           4.6 -4651.819578  2.045220
# 8   structure_17      171.0     179.4           4.6 -4651.818999  2.044853
# 43   structure_5      170.0     174.3           4.6 -4651.820501  2.046182
# 24  structure_31      172.2     146.8           4.9 -4651.822487  2.046472
#
#     energy_opt_vac      benzene       CH2Cl2        water  ...  \
# 25    -4649.776982 -4651.846038 -4651.868306 -4651.877649  ...
# 26    -4649.776963 -4651.845973 -4651.868196 -4651.877519  ...
# 3     -4649.774605 -4651.843760 -4651.868398 -4651.878851  ...
# 49    -4649.774580 -4651.843734 -4651.868364 -4651.878814  ...
# 4     -4649.774430 -4651.843747 -4651.868350 -4651.878790  ...
# 77    -4649.774405 -4651.843644 -4651.867820 -4651.877975  ...
# 66    -4649.774358 -4651.843601 -4651.867751 -4651.877895  ...
# 8     -4649.774146 -4651.843204 -4651.867754 -4651.878168  ...
# 43    -4649.774319 -4651.844488 -4651.868841 -4651.879173  ...
# 24    -4649.776015 -4651.844695 -4651.866985 -4651.876308  ...
#
#     association_vacuum  association_benzene  association_CH2Cl2  \
# 25          -57.474804           -28.982758           -3.520953
# 26          -57.462882           -28.942598           -3.452555
# 3           -55.983215           -28.854746           -4.880137
# 49          -55.967528           -28.835294           -4.855665
# 4           -55.873401           -28.722969           -4.726398
# 77          -55.857714           -28.578015           -4.313497
# 66          -55.828221           -28.532834           -4.252001
# 8           -55.695189           -28.514009           -4.484179
# 43          -55.803748           -28.485771           -4.332322
# 24          -56.868003           -28.433688           -2.985688
#
#     association_water  alpha_inp  beta_inp  distance_inp  energy_inp  \
# 25           6.198534      170.9     157.6           4.8 -311.154701
# 26           6.279483      169.4     159.9           4.8 -311.154669
# 3            4.142814      175.1     177.7           4.4 -311.159437
# 49           4.169170      161.0     175.8           4.5 -311.152445
# 4            4.304712      172.6     177.7           4.4 -311.159368
# 77           4.896453      145.0     149.6           5.8 -311.143414
# 66           4.964851      151.1     159.3           5.2 -311.147229
# 8            4.563245      176.0     178.3           4.4 -311.158199
# 43           4.766558      176.6     179.4           4.4 -311.160306
# 24           6.746349      174.4     147.0           4.9 -311.155186
#
#     rel_energy_inp_kcal  cluster_inp
# 25             3.905622            3
# 26             3.926167            3
# 3              0.933853            1
# 49             5.321841            1
# 4              0.977057            1
# 77            10.988793            3
# 66             8.594526            3
# 8              1.711092            1
# 43             0.388930            1
# 24             3.601557            3
#
# [10 rows x 23 columns]

# %%
inp_out.to_excel('comparison.xlsx')

# %%
inp_out['rel_vac'] = inp_out['association_vacuum'] - inp_out['association_vacuum'].min()
inp_out['rel_benzene'] = inp_out['association_benzene'] - inp_out['association_benzene'].min()
inp_out['rel_CH2Cl2'] = inp_out['association_CH2Cl2'] - inp_out['association_CH2Cl2'].min()
inp_out['rel_water'] = inp_out['association_water'] - inp_out['association_water'].min()

# %% [markdown]
# # Analysis of the opt data

# %% [markdown]
# Plot alpha vs beta

# %%
sns.set_context("talk")
sns.set_style("whitegrid", {"axes.edgecolor": "black"})
fig = plt.figure()
sns.scatterplot(data=inp_out, x='alpha_opt', y='beta_opt')

plt.xlim(0, 180)
plt.ylim(0, 180)
plt.xlabel('alpha')
plt.ylabel('beta')
plt.gcf().set_size_inches(8, 8)
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.scatterplot(data=inp_out, x='alpha_opt', y='beta_opt')

plt.xlim(140, 180)
plt.ylim(140, 180)
plt.xlabel('alpha')
plt.ylabel('beta')
plt.gcf().set_size_inches(8, 8)
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.scatterplot(data=inp_out, x='alpha_opt', y='beta_opt', hue='rel_vac', palette='icefire')

plt.xlim(0, 180)
plt.ylim(0, 180)
plt.xlabel('alpha')
plt.ylabel('beta')
plt.gcf().set_size_inches(8, 8)
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.scatterplot(data=inp_out, x='alpha_opt', y='beta_opt', hue='rel_vac', palette='icefire')

plt.xlim(140, 180)
plt.ylim(140, 180)
plt.xlabel('alpha')
plt.ylabel('beta')
plt.gcf().set_size_inches(8, 8)

plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.scatterplot(data=inp_out, x='alpha_opt', y='beta_opt', hue='rel_benzene', palette='icefire')

plt.xlim(0, 180)
plt.ylim(0, 180)
plt.xlabel('alpha')
plt.ylabel('beta')
plt.annotate(inp_out.iloc[72,0], (inp_out.iloc[72, 1], inp_out.iloc[72,2]))
plt.annotate(inp_out.iloc[70,0], (inp_out.iloc[70, 1], inp_out.iloc[70,2]))
plt.gcf().set_size_inches(8, 8)
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.scatterplot(data=inp_out, x='alpha_opt', y='beta_opt', hue='rel_benzene', palette='icefire')

plt.xlim(140, 180)
plt.ylim(140, 180)
plt.xlabel('alpha')
plt.ylabel('beta')
plt.gcf().set_size_inches(8, 8)
plt.annotate(inp_out.iloc[25,0], (inp_out.iloc[25, 1], inp_out.iloc[25,2]))
plt.annotate(inp_out.iloc[3,0], (inp_out.iloc[3, 1], inp_out.iloc[3,2]))
plt.annotate(inp_out.iloc[0,0], (inp_out.iloc[0, 1], inp_out.iloc[0,2]))
plt.tight_layout()
plt.show()

# %% [markdown]
# # Some statistics on the output data

# %%
sns.set_context("paper")
sns.set_style("white", {"axes.edgecolor": "black"})
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(10,5))
axs = axs.flatten()

sns.boxplot(inp_out['alpha_opt'], ax=axs[0])
ax=axs[0]
ax.set_ylabel('degrees')
ax.set_xlabel('alpha')
ax.set_ylim([0,180])
ax.set_xticks([])

sns.boxplot(inp_out['beta_opt'], ax=axs[1])
ax=axs[1]
ax.set_ylabel('degrees')
ax.set_ylim([0,180])
ax.set_xlabel('beta')
ax.set_xticks([])

sns.boxplot(inp_out['distance_opt'], ax=axs[2])
ax=axs[2]
ax.set_ylabel('angstrom')
ax.set_ylim([inp_out['distance_opt'].min()-1, inp_out['distance_opt'].max()+1])
ax.set_xlabel('distance')
ax.set_xticks([])

sns.histplot(inp_out['alpha_opt'], ax=axs[3])
ax=axs[3]
ax.set_xlim([40,180])
ax.set_xlabel('alpha')

sns.histplot(inp_out['beta_opt'], ax=axs[4])
ax=axs[4]
ax.set_xlim([40,180])
ax.set_xlabel('beta')

sns.histplot(inp_out['distance_opt'], ax=axs[5])
ax.set_xlabel('distance')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Clustering of output data

# %%
warnings.filterwarnings('ignore')
inertias = []
for i in range(1,11): # more than 10 clusters make no sense for 93 samples
    model = KMeans(n_clusters=i, random_state=123, max_iter=1000)
    model.fit(inp_out[['alpha_opt', 'beta_opt']])
    inertias.append(model.inertia_)

# %%
sns.set_context("notebook")
sns.set_style("whitegrid", {"axes.edgecolor": "black"})
fig = plt.figure(figsize=(6,4))
sns.lineplot(x=range(1,11), y=inertias, markers=True, marker='o')
plt.xlabel('# of clusters')
plt.ylabel('inertia')
plt.tight_layout()
plt.show()

# %%
model = KMeans(n_clusters=4, random_state=123, max_iter=1000)
model.fit(inp_out[['alpha_opt', 'beta_opt']])
inp_out['cluster_opt'] = model.labels_

# %%
sns.set_context("talk")
sns.set_style("whitegrid", {"axes.edgecolor": "black"})
fig = plt.figure()
sns.scatterplot(data=inp_out, x='alpha_opt', y='beta_opt', hue='cluster_opt', palette='seismic')

plt.xlim(0, 180)
plt.ylim(0, 180)
plt.xlabel('alpha')
plt.ylabel('beta')

plt.annotate(inp_out.iloc[72,0], (inp_out.iloc[72,1], inp_out.iloc[72,2]))
plt.gcf().set_size_inches(8, 8)
plt.tight_layout()
plt.show()

# %%
sns.set_context("notebook")
fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(10,8), sharey=True)
axs = axs.flatten()

for i in range(4):
    data = inp_out[inp_out['cluster_opt']==i]
    
    sns.boxplot(data=data, x='alpha_opt', ax = axs[i])
    
    ax = axs[i]
    ax.set_xlabel('')
    ax.set_xlim([40,180])
    ax.axvline(x=data['alpha_opt'].mean(), zorder=9, c='red', alpha=0.7)
    
for i in range(4):
    data = inp_out[inp_out['cluster_opt']==i]
    
    sns.boxplot(data=data, x='beta_opt', ax = axs[i+4])
    
    ax = axs[i+4]
    ax.set_xlim([40,180])
    ax.set_xlabel('')
    
    ax.axvline(x=data['beta_opt'].mean(), zorder=9, c='red', alpha=0.7)
for i in range(4):
    data = inp_out[inp_out['cluster_opt']==i]
    
    sns.boxplot(data=data, x='distance_opt', ax = axs[i+8])
    
    ax = axs[i+8]
    ax.set_xlabel('')
    ax.set_xlim([4,8])
    ax.axvline(x=data['distance_opt'].mean(), zorder=9, c='red', alpha=0.7)
    
for i in range(4):
    data = inp_out[inp_out['cluster_opt']==i]
    
    sns.boxplot(data=data, x='rel_benzene', ax = axs[i+12])
    
    ax = axs[i+12]
    ax.set_xlabel(f'cluster_{i}')
    ax.set_xlim([0,15])
    ax.axvline(x=data['rel_benzene'].mean(), zorder=9, c='red', alpha=0.7)

ax = axs[0]
ax.set_ylabel('alpha')
ax = axs[4]
ax.set_ylabel('beta')
ax = axs[8]
ax.set_ylabel('distance')
ax = axs[12]
ax.set_ylabel('energy_benzene')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Comparison of data

# %%
geometry = inp_out[['name', 'alpha_inp', 'beta_inp', 'alpha_opt', 'beta_opt', 'rel_benzene', 'rel_energy_inp_kcal', 'cluster_inp']]

# %%
geometry['dA'] = geometry['alpha_opt'] - geometry['alpha_inp']
geometry['dB'] = geometry['beta_opt'] - geometry['beta_inp']
geometry['dE'] = geometry['rel_benzene'] - geometry['rel_energy_inp_kcal']

# %%
geometry.sort_values('rel_benzene').head(10)
# Out:
#             name  alpha_inp  beta_inp  alpha_opt  beta_opt  rel_benzene  \
# 25  structure_32      170.9     157.6      175.0     146.8     0.000000
# 26  structure_33      169.4     159.9      174.9     147.0     0.040161
# 3   structure_12      175.1     177.7      171.5     179.5     0.128012
# 49  structure_55      161.0     175.8      171.6     179.5     0.147465
# 4   structure_13      172.6     177.7      171.5     179.5     0.259789
# 77  structure_82      145.0     149.6      158.6     172.9     0.404743
# 66  structure_71      151.1     159.3      158.5     173.1     0.449924
# 8   structure_17      176.0     178.3      171.0     179.4     0.468749
# 43   structure_5      176.6     179.4      170.0     174.3     0.496987
# 24  structure_31      174.4     147.0      172.2     146.8     0.549070
#
#     rel_energy_inp_kcal  cluster_inp    dA    dB         dE
# 25             3.905622            3   4.1 -10.8  -3.905622
# 26             3.926167            3   5.5 -12.9  -3.886006
# 3              0.933853            1  -3.6   1.8  -0.805841
# 49             5.321841            1  10.6   3.7  -5.174376
# 4              0.977057            1  -1.1   1.8  -0.717268
# 77            10.988793            3  13.6  23.3 -10.584050
# 66             8.594526            3   7.4  13.8  -8.144602
# 8              1.711092            1  -5.0   1.1  -1.242342
# 43             0.388930            1  -6.6  -5.1   0.108057
# 24             3.601557            3  -2.2  -0.2  -3.052486

# %%
geometry[geometry['dA'] == geometry['dA'].min()]
# Out:
#             name  alpha_inp  beta_inp  alpha_opt  beta_opt  rel_benzene  \
# 82  structure_89      121.1     165.6       87.1     171.3     3.600647
#
#     rel_energy_inp_kcal  cluster_inp    dA   dB       dE
# 82            12.659266            2 -34.0  5.7 -9.05862

# %%
inp_out[inp_out['alpha_opt']<100].sort_values('association_vacuum').head(10)
# Out:
#             name  alpha_opt  beta_opt  distance_opt      SPE_vac        dG  \
# 72  structure_78       51.7     135.9           5.8 -4651.819402  2.048746
# 86  structure_92       87.4     169.9           5.9 -4651.815597  2.045806
# 75  structure_80       87.6     171.3           5.9 -4651.815412  2.045836
# 47  structure_53       84.9     165.4           5.9 -4651.815570  2.046058
# 57  structure_62       84.8     166.8           5.9 -4651.815365  2.045865
# 82  structure_89       87.1     171.3           5.9 -4651.815300  2.045817
# 30  structure_38       90.9     172.5           5.7 -4651.815609  2.046252
# 45  structure_51       81.2     164.8           6.0 -4651.815249  2.046047
# 46  structure_52       81.3     164.7           6.0 -4651.815196  2.046012
# 28  structure_36       89.9     171.1           5.7 -4651.816315  2.047163
#
#     energy_opt_vac      benzene       CH2Cl2        water  ...  beta_inp  \
# 72    -4649.770656 -4651.843012 -4651.867388 -4651.877851  ...     126.2
# 86    -4649.769791 -4651.839376 -4651.863327 -4651.873372  ...     142.2
# 75    -4649.769576 -4651.839290 -4651.863447 -4651.873616  ...     162.9
# 47    -4649.769512 -4651.839747 -4651.864230 -4651.874539  ...     169.9
# 57    -4649.769500 -4651.839292 -4651.863514 -4651.873705  ...     170.9
# 82    -4649.769483 -4651.839177 -4651.863341 -4651.873519  ...     165.6
# 30    -4649.769357 -4651.838982 -4651.862395 -4651.872175  ...     173.0
# 45    -4649.769202 -4651.839436 -4651.863936 -4651.874255  ...     164.8
# 46    -4649.769184 -4651.839377 -4651.863868 -4651.874183  ...     165.2
# 28    -4649.769152 -4651.839607 -4651.862971 -4651.872744  ...     171.7
#
#     distance_inp  energy_inp  rel_energy_inp_kcal  cluster_inp   rel_vac  \
# 72           6.5 -311.146079             9.316507            0  3.969622
# 86           7.7 -311.138670            13.965627            2  4.512417
# 75           6.4 -311.145807             9.487233            0  4.647332
# 47           6.3 -311.152738             5.137711            0  4.687492
# 57           6.3 -311.150435             6.583021            0  4.695022
# 82           6.3 -311.140752            12.659266            2  4.705690
# 30           6.3 -311.153427             4.705201            0  4.784756
# 45           6.4 -311.152887             5.044476            0  4.882020
# 46           6.4 -311.152796             5.101033            0  4.893315
# 28           6.3 -311.153679             4.547263            0  4.913395
#
#     rel_benzene  rel_CH2Cl2  rel_water  cluster_opt
# 72     3.032123    3.068519   3.062244            2
# 86     3.468870    3.771957   4.027980            2
# 75     3.541661    3.715481   3.893693            2
# 47     3.394196    3.363448   3.453810            2
# 57     3.558604    3.691635   3.856043            2
# 82     3.600647    3.770074   3.942639            2
# 30     3.995977    4.636664   5.058978            2
# 45     3.582449    3.541033   3.625119            2
# 46     3.597509    3.561741   3.648337            2
# 28     4.175445    4.846880   5.273586            2
#
# [10 rows x 28 columns]

# %%
sns.set_context("talk")
sns.set_style("whitegrid", {"axes.edgecolor": "black"})
fig = plt.figure()
sns.scatterplot(data=geometry, x='dA', y='dE')
plt.xlim([-50, 50])
plt.ylim([-13, 5])

plt.xlabel('d_alpha')
plt.ylabel('d_energy_benzene')
plt.gcf().set_size_inches(8, 8)
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.scatterplot(data=geometry, x='dB', y='dE')
# plt.xlim([-50, 50])
# plt.ylim([-13, 5])

plt.xlabel('d_beta')
plt.ylabel('d_energy_benzene')
plt.gcf().set_size_inches(8, 8)
plt.tight_layout()
plt.show()

# %%
sns.set_context("notebook")
fig = plt.figure()
sns.barplot(data=geometry.sort_values('rel_benzene')[0:20], x='name', y='dA')
plt.xticks(rotation='vertical')
plt.title('alpha')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.barplot(data=geometry.sort_values('rel_benzene')[0:20], x='name', y='dB')
plt.xticks(rotation='vertical')
plt.title('beta')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.barplot(data=geometry.sort_values('rel_benzene')[20:40], x='name', y='dA')
plt.xticks(rotation='vertical')
plt.title('alpha')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.barplot(data=geometry.sort_values('rel_benzene')[20:40], x='name', y='dB')
plt.xticks(rotation='vertical')
plt.title('beta')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.barplot(data=geometry.sort_values('rel_benzene')[40:60], x='name', y='dA')
plt.xticks(rotation='vertical')
plt.title('alpha')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.barplot(data=geometry.sort_values('rel_benzene')[40:60], x='name', y='dB')
plt.xticks(rotation='vertical')
plt.title('beta')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.barplot(data=geometry.sort_values('rel_benzene')[60:80], x='name', y='dA')
plt.xticks(rotation='vertical')
plt.title('alpha')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.barplot(data=geometry.sort_values('rel_benzene')[60:80], x='name', y='dB')
plt.xticks(rotation='vertical')
plt.title('beta')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.barplot(data=geometry.sort_values('rel_benzene')[80:], x='name', y='dA')
plt.xticks(rotation='vertical')
plt.title('alpha')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.barplot(data=geometry.sort_values('rel_benzene')[80:], x='name', y='dB')
plt.xticks(rotation='vertical')
plt.title('beta')
plt.tight_layout()
plt.show()

# %%
sns.set_context("talk")
sns.set_style("whitegrid", {"axes.edgecolor": "black"})
fig = plt.figure()
sns.scatterplot(data=geometry, x='alpha_opt', y='rel_benzene')
# plt.xlim([-50, 50])
# plt.ylim([-13, 5])

plt.xlabel('alpha_opt')
plt.ylabel('energy_benzene')
plt.gcf().set_size_inches(8, 8)
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.scatterplot(data=geometry, x='alpha_inp', y='rel_energy_inp_kcal')
# plt.xlim([-50, 50])
# plt.ylim([-13, 5])

plt.xlabel('alpha_inp')
plt.ylabel('energy_inp')
plt.gcf().set_size_inches(8, 8)
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.scatterplot(data=geometry, x='beta_opt', y='rel_benzene')
# plt.xlim([-50, 50])
# plt.ylim([-13, 5])

plt.xlabel('beta_opt')
plt.ylabel('energy_benzene')
plt.gcf().set_size_inches(8, 8)
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.scatterplot(data=geometry, x='beta_inp', y='rel_energy_inp_kcal')
# plt.xlim([-50, 50])
# plt.ylim([-13, 5])

plt.xlabel('beta_inp')
plt.ylabel('energy_inp')
plt.gcf().set_size_inches(8, 8)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Removing duplicates from output by crest
#
# The `ensemble.xyz` is generated, which is similar to the output from the xtb docking procedure.
# It uses SPE (R2SCAN-3c) energy in vacuum for the energy sorting.
# Look at opt_structures_to_crest.ipynb for the code
#
# After successful crest run, the new sorted ensemble is renamed to crest_ensemble_orca.xyz and copied here.

# %%
df = pd.read_csv('crest_ensemble_orca.xyz')

# %%
# energy values

df_e = df[df.index % n_rows == 0].astype('float64')

# %%
final_df = inp_out.sort_values(by='SPE_vac').reset_index(drop=True)

# %%
df_e.columns = df_e.columns.str.strip()
df_e = df_e.rename(columns={'252':'SPE_vac'})
final_df = final_df.merge(df_e, on='SPE_vac')

# %%
final_df
# Out:
#             name  alpha_opt  beta_opt  distance_opt      SPE_vac        dG  \
# 0   structure_32      175.0     146.8           4.9 -4651.823922  2.046940
# 1   structure_37      169.8     151.5           4.9 -4651.822600  2.049079
# 2   structure_27      172.4     146.6           4.9 -4651.822523  2.046478
# 3   structure_22      170.3     151.5           4.8 -4651.822233  2.046635
# 4   structure_25      171.8     149.3           4.9 -4651.822095  2.046465
# 5   structure_21      167.3     158.5           4.8 -4651.820789  2.046433
# 6    structure_5      170.0     174.3           4.6 -4651.820501  2.046182
# 7   structure_19      161.7     164.2           4.8 -4651.820484  2.047195
# 8    structure_2      170.7     175.6           4.6 -4651.820032  2.046277
# 9   structure_47      170.8     145.3           4.9 -4651.819799  2.049622
# 10  structure_44      171.1     144.4           4.9 -4651.819709  2.050621
# 11  structure_82      158.6     172.9           4.6 -4651.819596  2.045191
# 12  structure_11      171.9     177.6           4.6 -4651.819536  2.045704
# 13  structure_13      171.5     179.5           4.6 -4651.819493  2.045063
# 14  structure_75      170.5     177.6           4.6 -4651.819426  2.045693
# 15  structure_78       51.7     135.9           5.8 -4651.819402  2.048746
# 16  structure_15      171.0     177.0           4.6 -4651.819243  2.045845
# 17  structure_14      171.0     177.0           4.6 -4651.819243  2.045848
# 18  structure_17      171.0     179.4           4.6 -4651.818999  2.044853
# 19  structure_46      146.9     174.5           4.5 -4651.818753  2.046390
# 20  structure_42      173.4     148.8           4.9 -4651.818371  2.045530
# 21  structure_30      169.8     172.7           4.5 -4651.818206  2.045216
# 22  structure_81      155.9     163.9           4.6 -4651.817978  2.047048
# 23  structure_29      161.4     169.6           4.6 -4651.817815  2.046870
# 24  structure_61      143.7     176.1           4.4 -4651.817643  2.045633
# 25  structure_56      155.7     168.6           4.6 -4651.817545  2.047224
# 26  structure_79      144.0     168.4           4.3 -4651.817106  2.048203
# 27  structure_36       89.9     171.1           5.7 -4651.816315  2.047163
# 28  structure_70      155.3     149.2           5.3 -4651.816169  2.045822
# 29  structure_88      148.8     171.4           4.5 -4651.815887  2.046228
# 30  structure_90      149.6     171.4           4.5 -4651.815773  2.045991
# 31  structure_93       79.3     156.9           5.7 -4651.815686  2.047212
# 32  structure_38       90.9     172.5           5.7 -4651.815609  2.046252
# 33  structure_92       87.4     169.9           5.9 -4651.815597  2.045806
# 34  structure_80       87.6     171.3           5.9 -4651.815412  2.045836
# 35  structure_89       87.1     171.3           5.9 -4651.815300  2.045817
# 36  structure_51       81.2     164.8           6.0 -4651.815249  2.046047
# 37  structure_77       86.4     170.7           5.9 -4651.814949  2.045899
# 38  structure_63       84.3     163.3           6.0 -4651.814808  2.046069
# 39  structure_39       85.6     166.6           5.9 -4651.814643  2.045940
# 40  structure_48       85.5     166.8           5.9 -4651.814551  2.045891
# 41  structure_58       85.6     167.7           5.9 -4651.814410  2.045972
# 42  structure_76       80.1     129.7           7.5 -4651.801196  2.044137
# 43  structure_67      106.3     145.9           7.5 -4651.797262  2.045603
# 44  structure_72      111.1     153.4           7.7 -4651.796848  2.043148
# 45  structure_68      104.5     145.4           7.6 -4651.796799  2.044442
# 46  structure_64      100.1     146.6           7.7 -4651.795875  2.043483
# 47  structure_66      100.2     145.9           7.7 -4651.795708  2.043385
#
#     energy_opt_vac      benzene       CH2Cl2        water  ...  beta_inp  \
# 0     -4649.776982 -4651.846038 -4651.868306 -4651.877649  ...     157.6
# 1     -4649.773521 -4651.844518 -4651.866693 -4651.876039  ...     164.5
# 2     -4649.776045 -4651.844645 -4651.866843 -4651.876125  ...     151.4
# 3     -4649.775598 -4651.844693 -4651.867332 -4651.876843  ...     155.8
# 4     -4649.775630 -4651.844609 -4651.867260 -4651.876757  ...     153.3
# 5     -4649.774356 -4651.843217 -4651.865854 -4651.875379  ...     155.6
# 6     -4649.774319 -4651.844488 -4651.868841 -4651.879173  ...     179.4
# 7     -4649.773289 -4651.843252 -4651.866056 -4651.875593  ...     178.5
# 8     -4649.773755 -4651.843817 -4651.867925 -4651.878140  ...     178.7
# 9     -4649.770177 -4651.842665 -4651.865883 -4651.875704  ...     147.4
# 10    -4649.769088 -4651.842386 -4651.865390 -4651.875108  ...     147.7
# 11    -4649.774405 -4651.843644 -4651.867820 -4651.877975  ...     149.6
# 12    -4649.773832 -4651.843657 -4651.868128 -4651.878510  ...     177.8
# 13    -4649.774430 -4651.843747 -4651.868350 -4651.878790  ...     177.7
# 14    -4649.773733 -4651.843595 -4651.868116 -4651.878521  ...     158.5
# 15    -4649.770656 -4651.843012 -4651.867388 -4651.877851  ...     126.2
# 16    -4649.773398 -4651.842812 -4651.866741 -4651.876899  ...     176.7
# 17    -4649.773395 -4651.842809 -4651.866735 -4651.876893  ...     176.8
# 18    -4649.774146 -4651.843204 -4651.867754 -4651.878168  ...     178.3
# 19    -4649.772363 -4651.842128 -4651.865532 -4651.875320  ...     176.2
# 20    -4649.772841 -4651.842892 -4651.867915 -4651.878556  ...     155.6
# 21    -4649.772990 -4651.842365 -4651.866858 -4651.877234  ...     165.2
# 22    -4649.770930 -4651.841794 -4651.865847 -4651.875980  ...     152.4
# 23    -4649.770945 -4651.841976 -4651.866450 -4651.876799  ...     175.5
# 24    -4649.772010 -4651.840729 -4651.863846 -4651.873512  ...     179.4
# 25    -4649.770321 -4651.841134 -4651.864691 -4651.874523  ...     177.4
# 26    -4649.768903 -4651.838516 -4651.859720 -4651.868495  ...     162.1
# 27    -4649.769152 -4651.839607 -4651.862971 -4651.872744  ...     171.7
# 28    -4649.770347 -4651.839209 -4651.862366 -4651.872068  ...     154.4
# 29    -4649.769659 -4651.839688 -4651.863690 -4651.873791  ...     159.6
# 30    -4649.769782 -4651.839650 -4651.863731 -4651.873866  ...     162.5
# 31    -4649.768474 -4651.839221 -4651.862935 -4651.872880  ...     150.5
# 32    -4649.769357 -4651.838982 -4651.862395 -4651.872175  ...     173.0
# 33    -4649.769791 -4651.839376 -4651.863327 -4651.873372  ...     142.2
# 34    -4649.769576 -4651.839290 -4651.863447 -4651.873616  ...     162.9
# 35    -4649.769483 -4651.839177 -4651.863341 -4651.873519  ...     165.6
# 36    -4649.769202 -4651.839436 -4651.863936 -4651.874255  ...     164.8
# 37    -4649.769050 -4651.838915 -4651.863184 -4651.873400  ...     166.3
# 38    -4649.768739 -4651.839105 -4651.863668 -4651.873994  ...     171.0
# 39    -4649.768703 -4651.838670 -4651.862946 -4651.873148  ...     173.1
# 40    -4649.768660 -4651.838701 -4651.863129 -4651.873403  ...     172.9
# 41    -4649.768438 -4651.838644 -4651.863137 -4651.873437  ...     169.9
# 42    -4649.757059 -4651.829733 -4651.858830 -4651.871135  ...     155.9
# 43    -4649.751659 -4651.825884 -4651.855035 -4651.867356  ...     154.2
# 44    -4649.753700 -4651.825923 -4651.855668 -4651.868292  ...     149.2
# 45    -4649.752357 -4651.825768 -4651.855319 -4651.867830  ...     154.9
# 46    -4649.752392 -4651.825422 -4651.855703 -4651.868592  ...     153.3
# 47    -4649.752323 -4651.825311 -4651.855583 -4651.868432  ...     154.6
#
#     distance_inp  energy_inp  rel_energy_inp_kcal  cluster_inp    rel_vac  \
# 0            4.8 -311.154701             3.905622            3   0.000000
# 1            4.7 -311.153497             4.661281            3   2.171809
# 2            4.7 -311.156440             2.814623            3   0.587976
# 3            4.8 -311.156918             2.514542            3   0.868472
# 4            4.8 -311.156625             2.698414            3   0.848392
# 5            4.8 -311.157655             2.052086            3   1.647839
# 6            4.4 -311.160306             0.388930            1   1.671056
# 7            4.4 -311.157808             1.956353            1   2.317391
# 8            4.4 -311.160894             0.019810            1   2.024972
# 9            5.0 -311.153094             4.914312            3   4.270199
# 10           5.0 -311.153141             4.884499            3   4.953556
# 11           5.8 -311.143414            10.988793            3   1.617091
# 12           4.4 -311.159708             0.763823            1   1.976653
# 13           4.4 -311.159368             0.977057            1   1.601403
# 14           5.0 -311.146966             8.759430            3   2.038777
# 15           6.5 -311.146079             9.316507            0   3.969622
# 16           4.4 -311.159111             1.138565            1   2.248992
# 17           4.4 -311.159236             1.059888            1   2.250875
# 18           4.4 -311.158199             1.711092            1   1.779616
# 19           4.6 -311.153097             4.912642            1   2.898464
# 20           4.8 -311.153230             4.829171            3   2.598515
# 21           4.5 -311.155239             3.568267            3   2.505016
# 22           4.4 -311.144870            10.074707            2   3.797684
# 23           4.5 -311.155515             3.395169            1   3.788272
# 24           4.6 -311.150955             6.256829            1   3.119975
# 25           4.5 -311.151800             5.726490            1   4.179837
# 26           4.6 -311.145993             9.370473            3   5.069645
# 27           6.3 -311.153679             4.547263            0   4.913395
# 28           7.6 -311.147295             8.553023            2   4.163522
# 29           6.2 -311.140892            12.570863            2   4.595248
# 30           6.2 -311.140566            12.775776            2   4.518065
# 31           7.9 -311.138529            14.053692            2   5.338847
# 32           6.3 -311.153427             4.705201            0   4.784756
# 33           7.7 -311.138670            13.965627            2   4.512417
# 34           6.4 -311.145807             9.487233            0   4.647332
# 35           6.3 -311.140752            12.659266            2   4.705690
# 36           6.4 -311.152887             5.044476            0   4.882020
# 37           6.7 -311.146123             9.288445            0   4.977401
# 38           6.4 -311.148934             7.524699            0   5.172557
# 39           6.3 -311.153407             4.717995            0   5.195147
# 40           6.3 -311.153066             4.931750            0   5.222130
# 41           6.3 -311.151418             5.965897            0   5.361437
# 42           7.7 -311.146620             8.976479            2  12.501862
# 43           7.7 -311.147724             8.284029            2  15.890410
# 44           7.6 -311.147208             8.608056            2  14.609665
# 45           7.7 -311.147653             8.328663            2  15.452409
# 46           7.7 -311.148868             7.566152            2  15.430446
# 47           7.7 -311.147734             8.277741            2  15.473744
#
#     rel_benzene  rel_CH2Cl2  rel_water  cluster_opt
# 0      0.000000    1.359184   2.055719            3
# 1      2.296055    3.713598   4.408251            3
# 2      0.584211    1.987321   2.722134            3
# 3      0.652609    1.778988   2.370101            3
# 4      0.598644    1.717492   2.317391            3
# 5      1.452056    2.579689   3.162018            3
# 6      0.496987    0.547815   0.623744            1
# 7      1.908255    2.931095   3.505893            1
# 8      0.977659    1.182227   1.331574            1
# 9      3.799567    4.562618   4.959204            3
# 10     4.601523    5.498861   5.960080            3
# 11     0.404743    0.566641   0.753638            1
# 12     0.718498    0.695280   0.739833            1
# 13     0.259789    0.153740   0.161897            1
# 14     0.750501    0.695907   0.726028            1
# 15     3.032123    3.068519   3.062244            2
# 16     1.337222    1.654114   1.839229            1
# 17     1.340987    1.659761   1.844876            1
# 18     0.468749    0.395958   0.420431            1
# 19     2.108430    2.754765   3.172058            1
# 20     1.089356    0.719753   0.601781            3
# 21     1.223015    1.185992   1.234310            1
# 22     2.730919    2.970000   3.170803            1
# 23     2.505016    2.479916   2.545177            1
# 24     2.511291    3.337720   3.831570            1
# 25     3.255517    3.805842   4.195525            1
# 26     5.512667    7.539521   8.592481            1
# 27     4.175445    4.846880   5.273586            2
# 28     3.583704    4.385033   4.856292            3
# 29     3.537896    3.808980   4.029863            1
# 30     3.413021    3.634532   3.834080            1
# 31     4.448411    4.900218   5.218992            2
# 32     3.995977    4.636664   5.058978            2
# 33     3.468870    3.771957   4.027980            2
# 34     3.541661    3.715481   3.893693            2
# 35     3.600647    3.770074   3.942639            2
# 36     3.582449    3.541033   3.625119            2
# 37     3.816510    3.920049   4.068768            2
# 38     3.803960    3.723011   3.802705            2
# 39     3.995977    4.095124   4.252628            2
# 40     3.945777    3.949542   4.061866            2
# 41     4.032373    3.995350   4.091359            2
# 42     8.472627    5.546552   4.384405            0
# 43    11.807837    8.847877   7.675690            0
# 44    10.242829    6.910129   5.547807            0
# 45    11.152090    7.941126   6.649713            0
# 46    10.767427    7.098382   5.569770            0
# 47    10.775585    7.112187   5.608675            0
#
# [48 rows x 28 columns]

# %% [markdown]
# The ensemble from crest had 47 structures, but here we see 48. It means that there were two structure with exactly the same SPE in the optimized dataset. We can locate and manualy delete this structure quite easily.

# %%
final_df['SPE_vac'].value_counts()
# Out:
# -4651.819243    2
# -4651.823922    1
# -4651.817545    1
# -4651.816315    1
# -4651.816169    1
# -4651.815887    1
# -4651.815773    1
# -4651.815686    1
# -4651.815609    1
# -4651.815597    1
# -4651.815412    1
# -4651.815300    1
# -4651.815249    1
# -4651.814949    1
# -4651.814808    1
# -4651.814643    1
# -4651.814551    1
# -4651.814410    1
# -4651.801196    1
# -4651.797262    1
# -4651.796848    1
# -4651.796799    1
# -4651.795875    1
# -4651.817106    1
# -4651.817643    1
# -4651.822600    1
# -4651.817815    1
# -4651.822523    1
# -4651.822233    1
# -4651.822095    1
# -4651.820789    1
# -4651.820501    1
# -4651.820484    1
# -4651.820032    1
# -4651.819799    1
# -4651.819709    1
# -4651.819596    1
# -4651.819536    1
# -4651.819493    1
# -4651.819426    1
# -4651.819402    1
# -4651.818999    1
# -4651.818753    1
# -4651.818371    1
# -4651.818206    1
# -4651.817978    1
# -4651.795708    1
# Name: SPE_vac, dtype: int64

# %% [markdown]
# There are two structures with energy -4651.819243 eh. We can locate and delete one of them.

# %%
final_df[final_df['SPE_vac'] == -4651.819243]
# Out:
#             name  alpha_opt  beta_opt  distance_opt      SPE_vac        dG  \
# 16  structure_15      171.0     177.0           4.6 -4651.819243  2.045845
# 17  structure_14      171.0     177.0           4.6 -4651.819243  2.045848
#
#     energy_opt_vac      benzene       CH2Cl2        water  ...  beta_inp  \
# 16    -4649.773398 -4651.842812 -4651.866741 -4651.876899  ...     176.7
# 17    -4649.773395 -4651.842809 -4651.866735 -4651.876893  ...     176.8
#
#     distance_inp  energy_inp  rel_energy_inp_kcal  cluster_inp   rel_vac  \
# 16           4.4 -311.159111             1.138565            1  2.248992
# 17           4.4 -311.159236             1.059888            1  2.250875
#
#     rel_benzene  rel_CH2Cl2  rel_water  cluster_opt
# 16     1.337222    1.654114   1.839229            1
# 17     1.340987    1.659761   1.844876            1
#
# [2 rows x 28 columns]

# %% [markdown]
# Let's delete structure 15.

# %%
final_df = final_df[final_df['name'] != 'structure_15'].reset_index(drop=True)

# %%
final_df.head(5)
# Out:
#            name  alpha_opt  beta_opt  distance_opt      SPE_vac        dG  \
# 0  structure_32      175.0     146.8           4.9 -4651.823922  2.046940
# 1  structure_37      169.8     151.5           4.9 -4651.822600  2.049079
# 2  structure_27      172.4     146.6           4.9 -4651.822523  2.046478
# 3  structure_22      170.3     151.5           4.8 -4651.822233  2.046635
# 4  structure_25      171.8     149.3           4.9 -4651.822095  2.046465
#
#    energy_opt_vac      benzene       CH2Cl2        water  ...  beta_inp  \
# 0    -4649.776982 -4651.846038 -4651.868306 -4651.877649  ...     157.6
# 1    -4649.773521 -4651.844518 -4651.866693 -4651.876039  ...     164.5
# 2    -4649.776045 -4651.844645 -4651.866843 -4651.876125  ...     151.4
# 3    -4649.775598 -4651.844693 -4651.867332 -4651.876843  ...     155.8
# 4    -4649.775630 -4651.844609 -4651.867260 -4651.876757  ...     153.3
#
#    distance_inp  energy_inp  rel_energy_inp_kcal  cluster_inp   rel_vac  \
# 0           4.8 -311.154701             3.905622            3  0.000000
# 1           4.7 -311.153497             4.661281            3  2.171809
# 2           4.7 -311.156440             2.814623            3  0.587976
# 3           4.8 -311.156918             2.514542            3  0.868472
# 4           4.8 -311.156625             2.698414            3  0.848392
#
#    rel_benzene  rel_CH2Cl2  rel_water  cluster_opt
# 0     0.000000    1.359184   2.055719            3
# 1     2.296055    3.713598   4.408251            3
# 2     0.584211    1.987321   2.722134            3
# 3     0.652609    1.778988   2.370101            3
# 4     0.598644    1.717492   2.317391            3
#
# [5 rows x 28 columns]

# %% [markdown]
# # Plot of the final data

# %%
sns.set_context("talk")
sns.set_style("whitegrid", {"axes.edgecolor": "black"})
fig = plt.figure()
sns.scatterplot(data=final_df, x='alpha_opt', y='beta_opt')

plt.xlim(0, 180)
plt.ylim(0, 180)
plt.xlabel('alpha')
plt.ylabel('beta')
plt.gcf().set_size_inches(8, 8)
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.scatterplot(data=final_df, x='alpha_opt', y='beta_opt')

plt.xlim(140, 180)
plt.ylim(140, 180)
plt.xlabel('alpha')
plt.ylabel('beta')
plt.gcf().set_size_inches(8, 8)
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.scatterplot(data=final_df, x='alpha_opt', y='beta_opt', hue='rel_benzene', palette='icefire')

plt.xlim(0, 180)
plt.ylim(0, 180)
plt.xlabel('alpha')
plt.ylabel('beta')
plt.gcf().set_size_inches(8, 8)
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.scatterplot(data=final_df, x='alpha_opt', y='beta_opt', hue='rel_benzene', palette='icefire')

plt.xlim(140, 180)
plt.ylim(140, 180)
plt.xlabel('alpha')
plt.ylabel('beta')
plt.gcf().set_size_inches(8, 8)
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
sns.scatterplot(data=final_df, x='distance_opt', y='rel_benzene')

# plt.xlim(140, 180)
# plt.ylim(140, 180)
plt.xlabel('D')
plt.ylabel('dE')
plt.gcf().set_size_inches(8, 8)
plt.tight_layout()
plt.show()

# %%
loc_s = 127
loc_cs = 182
loc_n = 1
loc_cn = 61

# %%
def geometry_from_xyz_2(folder):
    pattern_xyz = 'struc_[0-9]+_r2scan_opt\.xyz'
    file_name = [i for i in os.listdir(f'{folder}/') if re.findall(pattern_xyz, i)][0] # get the name of correct xyz
    with open(f'{folder}/{file_name}', 'r', encoding='utf-8') as xyz:
        lines = xyz.readlines()
        no_of_atoms = int(lines[0][:-1]) # get number of atoms
        
        # get the lines containing the atoms we need
        
        n_coord = np.array([float(i) for i in lines[loc_n+1].strip().split()[1:]])
        cn_coord = np.array([float(i) for i in lines[loc_cn+1].strip().split()[1:]])
        s_coord = np.array([float(i) for i in lines[loc_s+1].strip().split()[1:]])
        cs_coord = np.array([float(i) for i in lines[loc_cs+1].strip().split()[1:]])
        
        # calculate the corresponding angles
        # alpha
        
        vector_n_cn = cn_coord - n_coord
        vector_n_cs = cs_coord - n_coord
        len_n_cn = np.sqrt(np.square(vector_n_cn).sum())
        len_n_cs = np.sqrt(np.square(vector_n_cs).sum())
        
        cos_a = np.dot(vector_n_cn, vector_n_cs)/(len_n_cn*len_n_cs)
        alpha = np.around(np.degrees(np.arccos(cos_a)), decimals=1)
        
        # beta
        
        vector_s_cn = cn_coord - s_coord
        vector_s_cs = cs_coord - s_coord
        len_s_cn = np.sqrt(np.square(vector_s_cn).sum())
        len_s_cs = np.sqrt(np.square(vector_s_cs).sum())
        
        cos_b = np.dot(vector_s_cs, vector_s_cn)/(len_s_cs*len_s_cn)
        beta = np.around(np.degrees(np.arccos(cos_b)), decimals=1)
        
        # distance
        dist = np.around(np.sqrt(np.square(cn_coord - cs_coord).sum()), decimals=1)
               
        
        
    return alpha, beta, dist

# %%
outputs_2 = pd.DataFrame(columns=['name', 'alpha_opt', 'beta_opt', 'distance_CC', 'SPE_vac', 'dG'])
for folder in folders:
    alpha, beta, dist = geometry_from_xyz_2(folder)
    spe = r2scan_spe_vacuum(folder)
    dG = hess_reader(folder)
    
    outputs_2.loc[len(outputs_2.index)] = [folder, alpha, beta, dist, spe, dG]

# %%
outputs_2
# Out:
#             name  alpha_opt  beta_opt  distance_CC      SPE_vac        dG
# 0    structure_1      168.7     171.9         23.5 -4651.819516  2.046003
# 1   structure_10      168.7     172.0         23.5 -4651.819510  2.045981
# 2   structure_11      171.1     174.4         23.5 -4651.819536  2.045704
# 3   structure_12      170.6     174.7         23.5 -4651.819471  2.044866
# 4   structure_13      170.7     175.0         23.5 -4651.819493  2.045063
# ..           ...        ...       ...          ...          ...       ...
# 88   structure_9      168.7     171.9         23.5 -4651.819517  2.045993
# 89  structure_90      154.2     173.2         22.8 -4651.815773  2.045991
# 90  structure_91      169.1     171.8         23.5 -4651.819200  2.046323
# 91  structure_92       89.8     133.3         18.3 -4651.815597  2.045806
# 92  structure_93       79.5     117.7         16.9 -4651.815686  2.047212
#
# [93 rows x 6 columns]

# %%
fig = plt.figure()
sns.scatterplot(x=outputs_2['distance_CC'], y=combined['association_benzene'])

# plt.xlim(140, 180)
# plt.ylim(140, 180)
plt.xlabel('distance')
plt.ylabel('assoc. benzene')
plt.gcf().set_size_inches(7, 7)
plt.tight_layout()
plt.show()
